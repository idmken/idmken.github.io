# %%
import pandas as pd

# %%
jobs = pd.read_json("data-job-fed-20220323.json")

# %%
jobs.head()
# Out:
#                                   source                                title  \
# 0                                   None                                 None
# 1  https://www.usajobs.gov/job/686009900    Information Technology Specialist
# 2  https://www.usajobs.gov/job/685440700  SUPERVISORY IT SPECIALIST (INFOSEC)
# 3  https://www.usajobs.gov/job/682294500    SUPV IT PROJECT MANAGER (PLCYPLN)
# 4  https://www.usajobs.gov/job/680672600                   IT Program Manager
#
#                                                  org  \
# 0                                               None
# 1  National Aeronautics and Space Administration ...
# 2                    General Services Administration
# 3                              Department of Defense
# 4                              Department of Defense
#
#                                             division    openDate   closeDate  \
# 0                                               None  00/00/0000  00/00/0000
# ...
