# %%
import pandas as pd

# %%
industry = pd.read_json("data-job-industry-20221101.json")

# %%
industry.head()
# Out:
#                             Keyword         Location  Page  \
# 0   Identity and access management    United States      1
# 1   Identity and access management    United States      1
# 2   Identity and access management    United States      1
# 3   Identity and access management    United States      1
# 4   Identity and access management    United States      1
#
#                          company rating  \
# 0                             EY    3.9
# 1  Consolidated Nuclear Security    3.9
# 2                    Capital One    4.2
# 3       Alterra Mountain Company    3.8
# 4             Putnam Investments    3.8
#
#                                            Job_title Place  \
# 0  Identity and Access Management IC Identity Spe...
# 1               Identity Access Management Developer
# 2  Sr. Software Engineer - Identity Access Manage...
# 3               Systems Analyst, Identity and Access
# 4      Identity and Access Management (IAM) Engineer
#
# ...
