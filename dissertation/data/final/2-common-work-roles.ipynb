# %% [markdown]
# # Identify Common Work Roles

# %% [markdown]
# ## 1. Import Packages

# %%
import nltk
import requests
import numpy as np
from pathlib import Path
from nltk.corpus import stopwords
from nltk import ngrams
import re

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/kenmye/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 2. Load the Data set

# %%
data = Path('../project_data/data-job-title.txt').read_text()

print(data)
# Out:
# Identity and Access Management Senior Security Engineer.
# Azure DevOps Engineer.
# Senior Data Analyst.
# IAM Engineer.
# Engineer, Application Security (Identity & Access Management platform SME).
# Data Analyst (Remote).
# Identity and Access Management engineer.
# REMOTE - Cybersecurity Senior Manager - Cloud Identity and Access Management.
# VP, Product Management.
# Oracle Access/Identity Management Application Developer.
# Data & Analytics Product Owner (Remote - Home Based Worker).
# REMOTE Golang Developer.
# REMOTE C++ Developer (Multithreading).
# Identity and Access Management - Manager.
# Sr SAP Security and GRC Lead Remote.
# Data Analyst.
# Manager, Identity Engineering.
# Identity Access Management (IAM) Engineer.
# Identity and Access Management Engineer.
# Director Information Security, Identity Access Management.
# Identity and Access Management Manager- Remote.
# Associate Director, Product Owner for Identity and Access Management.
# Front End Developer - Identity & Access Management.
# Identity & Access Management Product Specialist -.
# Senior Identity Access Management (IAM) Engineer.
# Senior DevOps Engineer.
# Data Scientist.
# Technical Business Analyst, Principle Identity and Access Management.
# Global Head of ICRM/AML Compliance - Data Governance and Data Integrity.
# Analytics Security Architect (Hybrid/Remote).
# Identity Access Management Team Lead.
# Identity Access Management Engineer II.
# Principal PM Manager - Conditional Access (Identity Access Management).
# Identity and Access Management Engineering Team Lead.
# Privileged Access Management Engineering Team Lead.
# Backend Software Engineer, Identity Administration.
# Sentinel (GBSD) – Staff Data Management Analyst – 3036-1.
# Head of Global Identity and Access Management-Cyber Security Services.
# Identity and Access Management Governance: Senior Resource.
# Senior Program Manager.
# Product Owner- Storage and Backup.
# Director IT Service Operations.
# Software Engineer.
# Director of Engineering.
# Principal PM Management.
# Access Management Coordinator.
# Software Development Engineer , AWS Identity and Access Management.
# Director Identity and Access Management (100% Virtual).
# Engineering/Architecture - Identity Management.
# Information Security Analyst.
# Chief Technology Officer.
# IAM Architect.
# Cybersecurity Senior Engineer (Remote).
# Cybersecurity Senior Engineer (Remote).
# Cybersecurity Staff Analyst (Remote).
# Cybersecurity Staff Analyst (Remote).
# Lead Director, Identity and Access Management.
# IAM and Security Architect.
# MTS Software Engineer.
# Senior Identity and Access Management (IAM) Engineer.
# Senior Identity and Access Management (IAM) Engineer.
# Privileged Access Management (PAM) Engineer - HYBRID - FULL TIME.
# VP of Data and Reporting- Remote NJ.
# IDENTITY & ACCESS MANAGEMENT MANAGER.
# Identity & Access Management (IAM) Leader.
# Sr Director, Analyst - Identity and Access Management.
# Principal Product Manager–Tech, Identity and Access Management.
# Cybersecurity Analyst (Remote).
# Cybersecurity Engineer (Remote).
# Manager, Fraud and Risk Management, Cyber and Intelligence Solutions.
# Engineering Manager, Identity and Access Management (US Remote).
# Fully Remote - Technical Project Manager (Identity & Access Management).
# Senior Engineering Manager (Identity & Access Management).
# Identity and Access Management Lead (USDS) - New York.
# Director, Product Management.
# IAM Engineer.
# Cybersecurity Staff Engineer (Remote).
# Cybersecurity Staff Engineer (Remote).
# Identity and Access Management Engineer.
# Senior Director and Head of Product Management.
# Staff Engineer, Identity & Access Management Engineering.
# Director, Business Strategy.
# Identity & Access Management Security Engineer (Remote).
# Director, Business Operations.
# Director – C360 Digital Product Management.
# Staff Engineer, Air Vehicle Configuration Design and Integration.
# Identity and Data Management Manager.
# Director of Global Information Security - Identity and Access Management (IAM).
# Director of Global Information Security - Identity and Access Management (IAM).
# Sr. Software Engineer III, AWS IAM (Identity and Access Management).
# Head of Information Security & Privacy.
# Cybersecurity Manager (Remote).
# Cybersecurity Manager (Remote).
# Director Information Security – Technology Exam Management & Industry Relations- REMOTE OR HYBRID.
# Director Information Security-Privileged Access Management (PAM)- REMOTE OR HYBRID.
# Cybersecurity Engineer II (Remote).
# Director, Product Management, Monetization (Remote).
# Site Reliability Engineer.
# Site Reliability Engineer.
# Head of Data Science.
# Cybersecurity Staff Engineer (Remote).
# Principal Foundational Architect‚ÄîIdentity & Access Management Platforms (Remote Option*).
# Technology Associate.
# VP, Engineering.
# VP, Engineering.
# Identity and Access Management Analyst.
# Identity and Access Management Engineer.
# Data Analyst (College Grad).
# Identity and Access Management (IAM) Engineer (REMOTE OPPORTUNITY).
# Cybersecurity Staff Engineer - Endpoint Detection and Response (Remote).
# Java Developer.
# Customer Identity and Access Management (CIAM) Product Owner (REMOTE OPPORTUNITY).
# Access Provisioning Analyst.
# Service Desk Associate (Remote).
# Identity and Access Management Specialist I - Identity Access Mgmt IAM, Full Time.
# Identity and Access Management Administrator.
# IAM/ForgeRock Consultant- 100% Remote.
# Identity Access Administrator.
# Payroll Implementation Specialist - Remote.
# Logistics Data Management Specialist.
# Identity and Access Management Analyst.
# Identity and Access Management Engineer - IAM (SailPoint IIQ).
# Applications Support Analyst (Mid-Level).
# Data Privacy Analyst.
# Identity and Access Management Analyst.
# Salesforce Quality Assurance Specialist.
# Maestro Care Application Analyst - Duke Health Technology Solutions - Remote.
# Engineer for Identity and Access Management and Related Technologies.
# Supervisor of Identity and Access Management.
# Security Engineer – Identity and Access Management-Open to Remote.
# Identity and Access Management (IAM) Administrator.
# Identity and Access Management Analyst (Remote).
# Remote Identity & Access Management Security Administrator - IAM Administrator (100% Remote).
# Basic Needs Project Assistant.
# Identity and Access Management.
# Identity and Access Management Analyst.
# Identity Access Management.
# web access management.
# Data Engineer - $70/hr (Remote Role).
# Jr Help Desk Tech.
# Systems Administrator (Hybrid Remote).
# Identity and Access Management Analyst (remote).
# IT Web App Developer.
# Manual QA Engineer - 100% REMOTE.
# Identity and Access Management Architect.
# HRIS Analyst I.
# Front End Developer - REMOTE.
# Environmental Director, Water and Wastewater.
# Systems Engineer/Sr Systems Engineer (Identity & Access Management).
# Identity and Access Management Administrator.
# Assoc. Identity & Access Management Analyst.
# Associate Technical Consultant, Okta / Identity and Access Management.
# Data Management Analyst.
# IAM Support Engineer.
# Quality Assurance Analyst.
# Database Administrator - 100% REMOTE.
# Identity and Access Management Engineer (Hybrid Remote).
# Identity and Access Management Engineer "virtual".
# Associate Engineer II, Identity and Access Management.
# Sr Information Security Analyst (Remote).
# Tester.
# Identity and Access Management Developer.
# Cybersecurity and Privacy Associate - Summer 2023.
# Identity and Access Management (IDAM) Operations Analyst.
# Identity and Access Management Analyst II.
# Identity and Access Management IC Identity Specialist - Contractor.
# IAM Architect, Authentication and Access Management.
# IAM Siteminder Admin.
# Cloud Identity and Access management (IAM) Specialist.
# SailPoint Developer.
# Identity Governance Architect.
# IAM Engineer.
# Security Engineer - Identity & Access Management (H).
# Manager of Product Management - Identity and Access Management.
# Data Engineer - December 2022 and May 2023 Graduates.
# Identity & Access Control Administrator.
# IT Administrator/Helpdesk.
# IT Administrator/Helpdesk L2/L3.
# Identity and Access Management (IAM) Solution Engineer.
# Remote Quality Systems Management Specialist.
# Lead Identity Access Management (IAM) Developer.
# Lead Identity Access Management (IAM) Developer.
# Identity Access Management Developer.
# Identity and Access Management Engineer.
# Business Analyst II - Remote Available.
# Identity and Access Management (IAM) Analyst.
# Identity and Access Management Engineer II.
# Customer Identity Access Management (IAM) Engineer.
# Product Management Analyst (US - Remote).
# Identity and Access Management Analyst.
# Identity and Access Management (IDAM) Administrator.
# QA Engineer.
# Software Engineer (No Compensation-Volunteer-Part Time-Remote).
# Manager - Identity Access Management.
# REMOTE IAM Platform Developer.
# Systems Analyst, Identity and Access.
# Project Manager - Identity and Access Management (Mid-Atlantic).
# Identity Access Mgmt. Analyst.
# CyberArk IAM Architect - Identity Access Manager Architect.
# Senior Identity and Accesss Management Engineer.
# Junior / Midlevel IT Support Engineer.
# Sr. Cyber Analyst - Identity & Access Management.
# Identity and Access Management-Business.
# Identity and Access Management (IdAM) Systems Engineer.
# Mid-level Business Analyst (Remote).
# Systems Engineer - Identity and Access Management.
# Identity & Access Management Architect (IAM) -100% remote.
# Project Manager - Identity and Biometric Solutions- Pasadena or Remote.
# Arity - Associate Product Manager.
# Application Developer (Remote).
# Identity & Access Management Analyst.
# Identity and Access Management Project Manager.
# Identity and Access Management Engineer.
# Manager, Identity and Access Management (Hybrid or Remote).
# Identity and Access Management-Business.
# Identity and Access Management Analyst.
# Identity and Access Management Developer.
# Identity & Access Management Analyst.
# Identity and Access Management Systems Administrator (0520U), Berkeley IT - 41278.
# Senior Helpdesk Specialist (Remote).
# Identity Business Analyst/IGA.
# Security And O365 Security Architect.
# IAM Engineer.
# Identity and Access Management Developer.
# Identity Access Management (IAM) Developer.
# Secrets & Privileged Access Management Engineer.
# Engineer – Identity & Access Management.
# Application Software Developer.
# Senior IAM Technical Analyst.
# Jr. Front End Developer.
# IAM Engineer( Saviynt, Sailpoint, ForgeRock AM ).
# Business Analyst (Remote).
# Identity and Access Management Engineer (Remote).
# Associate - Global Markets Audit Issues, Third Party, and Access Management Governance and Oversight.
# Reliability Operations Identity & Access Management Analyst.
# Identity and Access Management Engineer.
# Identity & Access Management Solution Consultant - Remote/Delivery Center role.
# Identity and Access Management Engineer.
# Identity Governance and Access Engineer (REMOTE).
# Identity& Access Management Sales Executive_selling IAM products & services.
# ISD Engineer II/III (Customer Identity Access Management).
# IT Identity & Access Management Developer - Sailpoint - Remote.
# Sr Identity Access Management Consultant - Zero Trust - Remote.
# ForgeRock Identity Management Engineer.
# Lead Identity and Access Management Architect.
# Identity & Access Management (IAM) Engineer.
# Identity and Access Management LEAD.
# Oracle Identity and Access Management Developer.
# SailPoint Identity and Access Management Analyst.
# Senior Data Governance / Privacy Consultant.
# Identity and Access Management Director.
# Product Manager, Identity and Access Management (IAM).
# SAML & Federation Technical Lead - Identity and Access Management, VP (C13).
# SAML & Federation Technical Lead - Identity and Access Management, VP (C13).
# Product Owner / Manager - Identity and Access Management.
# Identity and Access Management Authentication Services Engineer.
# Java Application Developer (Remote).
# Identity and Access Management (IAM) Engineer.
# Identity and Access Management Manager.
# Identity Access Management Project Management, IT Officer.
# Innovation Data Strategist.
# Data Management and Governance Strategist.
# Identity and Access Management Engineer.
# HRIS SQL Developer.
# Identity & Access Management (IAM) Engineer.
# Identity & Access Management (IAM) Engineer.
# Identity and Access Management- Senior Consultant -.
# Identity and Access Management Engineer.
# Senior Business Analyst - Identity and Access Management (IAM).
# Data Analyst.
# Product Owner (Remote).
# Identity and Access Management Engineer.
# Identity and Access Management Engineer.
# Identity and Access Management Engineer.
# Identity and Access Management Analyst.
# Identity and Access Management Analyst.
# Identity & Access Management Engineer.
# Privileged Access Management Engineer.
# Cybersecurity Engineer (Remote).
# Cybersecurity Analyst (Remote).
# Front End Developer.
# Lead Business Analyst, Identity & Access Management.
# Manager of Identity & Access Management.
# Identity Access Management AD Systems Administrator.
# Data Scientist.
# Firmware and Hardware Engineer.
# Analyst II - Security Compliance.
# Digital Transformation Product Management.
# Senior Identity Access Management Specialist.
# Identity and Access Management Engineer (Hybrid Remote).
# Identity and Access Management Engineer.
# Software Development Engineer I.
# Scrum Master.
# Director of Reporting and Analytics 2022-1235 Hybrid.
# Lead Software Engineer - Identity and Access Management (IAM).
# Manager, Identity and Access Management (IAM).
# Identity and Access Management Engineer.
# Identity & Access Management Engineer (Contract Remote).
# Oracle Identity and Access Management Engineer.
# Sr. Analyst, Identity and Access Mgmt (Remote).
# Identity & Access Management Engineer- REMOTE.
# Identity & Access Management Engineer/SailPoint.
# Director, Software Engineering - Remote - All US.
# Identity Access Management - SSO SME.
# DevOps Engineer (Remote).
# Senior Identity and Access Management Engineer - CIAM.
# Systems Engineer, Identity and Access.
# Sr. Information Security Consultant - Remote.
# Software Engineer - Opportunity for Working Remotely New York, NY.
# Identity and Access Management Engineer (Remote).
# Data Engineer.
# Senior Security Analyst - Customer Trust.
# Data Analytics & Reporting Analyst.
# Identity & Access Management Engineer (Remote).
# Lead Identity and Access Management Engineer.
# IAM Engineer.
# Software Engineer, IT Security and Access.
# 2023: Back End Developer Co-op.
# Management Consultant.
# Senior Manager, Data Management and Privacy.
# Senior Manager - Identity & Access Management.
# Identity Access Management Consultant.
# Data Integration Developer.
# Power BI Engineer Remote.
# Identity & Access Management Engineer.
# Cybersecurity Engineer.
# Cybersecurity Risk Manager (Remote Work Schedule).
# Business Intelligence Engineer, Identity and Access Management.
# Sr. Software Engineer - Identity & Access Management.
# Identity and Access Management Admin/Sr. Engineer.
# Cybersecurity Engineer II (Remote).
# Cybersecurity Engineer II (Remote).
# Senior Data Scientist - Remote.
# Product Owner / Manager - Identity and Access Management.
# Product Owner, Identity & Access Management.
# Senior Identity and Access Management Engineer.
# Identity and Access Management architect.
# Software Development Engineer.
# Cybersecurity Engineer 4.
# information security engineer sr-identity management.
# Identity & Access Management Engineer.
# Identity & Access Management Engineer.
# Data Scientist II - AI and Machine Learning.
# Sr. Director, Program Management, Experian BIS (Open to Remote).
# Data Scientist II - AI/ML.
# Kubernetes DevOps Engineer.
# Identity and Access Management Lead.
# Global Identity and Access Management Sr Java Developer.
# Identity and Access Management Architect.
# Identity & Access Management Lead Engineer-Identity Governance.
# Lead Identity and Access Management Architect.
# Front End Developer - Identity & Access Management.
# Product Manager.
# Global PHC Cybersecurity Leader.
# Epic Beacon Application Analyst Sr.
# Data Engineer, Identity & Access Management (Austin OR Arlington).
# Sr. Product Manager (Hybrid Remote).
# Director, Identity and Access Management.
# SAP Quality Management Consultant.
# Identity and Access Management Manager.
# Customer Experience Data Analyst.
# Manager, Identity Access Management.
# Application Developer II (US Remote).
# (IAM) Principal Product Owner.
# IT Manager - Privileged Access Management.
# Scrum Master.
# Identity and Access Management Senior Business/Technical Analyst - Remote.
# SailPoint Identity and Access Management Senior Business/Technical Analyst - Remote.
# SailPoint Identity and Access Management Engineer.
# Manager, Data Loss Prevention (DLP) Manager (Remote-Eligible).
# Principal Associate, Date Loss Prevention (DLP) Analyst (Remote-Eligible).
# Senior Manager, Cyber Product Management, Data Protection and DLP Solutions (Remote-Eligible).
# Senior Manager, Cyber Product Management, Data Protection and DLP Solutions (Remote-Eligible).
# Senior Manager, Cyber Product Management, Data Protection and DLP Solutions (Remote).
# Sr. Software Engineer - Identity Access Management (Remote Eligible).
# Sr. Software Engineer - Identity Access Management (Remote Eligible).
# Senior Data Engineer, Enterprise Data (Remote-Eligible).
# Senior Manager, Data Management and Privacy.
# Principal Associate, Date Loss Prevention (DLP) Analyst (Remote-Eligible).
# Senior Director, Technology -Technical Program Management (Remote Eligible).
# Engineer, Identity and Access Management.
# Identity and Access Management Solutions Architect.
# Technology and Data Analyst.
# Technology and Data Analyst.
# Workforce Identity and Access Management Architect.
# Identity and Access Management Engineer.
# Senior Cybersecurity Engineer - Privilege Access Management (PAM).
# Business Analyst I-Remote.
# VP, Business & Technology Transformation.
# Identity, Credential and Access Management (ICAM) Architect.
# Infrastructure Engineer ( DevOps / AWS / Linux ).
# Identity & Access Management Engineer - ForgeRock.
# Identity and Access Management Developer.
# Oracle Access Manager.
# Group Product Manager, Consumer Discovery & Engagement.
# Senior Program Manager, Engineering.
# Identity Access Management (IAM) Consultant - Temp.
# Identity & Access Management Engineer.
# Director Analyst, Identity and Access Management (Flexible Remote NA Location).
# Project/Program Manager - Level 3- Remote.
# Director, Customer Information and Access Management.
# DoD Identity and Access Management Engineer.
# Identity & Access Management Engineer, Senior Consultant.
# Senior Director, Change and Transformation Enablement.
# Technical Analyst (C).
# Front End Developer.
# Senior Director - Identity and Access Management (IAM) for Health Benefits (a subsidiary of Health Care Service Corporation).
# Identity Access Management Architect.
# Identity and Access Management Engineer.
# Director, Identity and Access Management.
# Identity and Access Management Engineer 2.
# Identity and Access Management Director.
# Sr, Identity and Access Management Engineer.
# Identity and Access Management Engineer.
# Customer Support Engineer I.
# UI Developer (Remote).
# Identity and Access Management Developer.
# Technology Manager - Identity & Access Management.
# Data Management Analyst.
# SailPoint Engineer.
# Product Owner / Manager - Identity and Access Management.
# LMS Administrator.
# Product Marketing Manager - Identity and Access Management.
# Director, Identity Governance and Oversight.
# Oracle SSO Identity and Access Administrator.
# Data Scientist.
# Data Scientist 1.
# Data Analyst.
# Technology Engineer ( Identity & Access Management ).
# VP.
# Identity and Access Management/Governance Architect.
# Identity & Access Management Technologies Leader.
# Identity Access Management Engineer I - Remote.
# Business Analyst - Remote | 898168.
# Director of IT.
# IAM Saviynt Consultant.
# Vice President of Engineering.
# Junior Software Engineer [Hybrid].
# IAM Ping Expert.
# IT System Developer (Customer IAM).
# Identity and Access Management Analyst.
# Cloud Security Engineer.
# Identity Access Management (IAM) Analyst.
# Identity Access Management Analyst.
# Security Log Management Analyst.
# Software Development Engineer.
# SOC Analyst.
# Verizon Senior Manager - Device Identity Access Management - Bellevue, WA.
# Lead Data Management Analyst.
# Senior Data Management Analyst.
# Associate Director - Identity and Access Mgt.

# %% [markdown]
# ## 3. Tokenize words

# %%
#Tokenize words.
wordtext=data.replace('\n','')
token=re.findall('\w+', wordtext)

# %% [markdown]
# ## 4. Work Role Analysis - Clean dataset

# %%
#ETL words into all lowercase.
words=[]
for word in token:
    words.append(word.lower())

#print(words)

#Create stopword list.
stopword = stopwords.words('english')
newStopWords =  ['identity', 'access','management','senior','security','azure','data','devops','iam','application','platform','sme','remote','cybersecurity','cloud','product', 'oracle','analytics','home', 'based', 'worker', 'golang','c','multithreading','sr', 'sap', 'grc','engineering','information','front', 'end','technical', 'business','principle', 'global','icrm', 'aml', 'compliance', 'governance', 'integrity','hybrid', 'team','ii','pm','conditional', 'team','privileged','backend', 'software','administration', 'sentinel', 'gbsd', 'staff','3036', '1','cyber', 'services', 'governance', 'resource', 'program','owner', 'storage', 'backup','service', 'operations', 'software','systems','mgmt','mid','iii','idam','ai','customer','site','care','date','ciam','admin','sso','air', 'vehicle', 'configuration', 'design', 'integration','sailpoint', 'iiq', 'applications', 'support','helpdesk', 'l2', 'l3', 'solution','web', 'app', 'manual', 'qa', '100', 'hris','december', '2022', 'may', '2023', 'graduates', 'control','assoc', 'dod', 'level', 'assurance', 'scrum', 'maestro', 'detection', 'sales', 'ml', 'open', 'protection', 'atlantic', 'lms', 'privacy','accesss', 'iga', 'saml', 'center', 'mgt', 'ad', 'role', 'icam', 'tester', 'engagement', 'system', 'secrets', 'needs', 'dlp', 'isd', 'arity', 'eligible', 'co', 'grad', 'strategy', 'digital', 'siteminder', 'trust', 'contractor', 'contract', 'soc', 'ui', 'issues', 'location', 'log', 'transformation', 'prevention', 'learning', 'austin', 'relations', 'college', 'related', 'arlington', 'summer', 'remotely', 'loss', 'na', 'ic', 'ny', 'assistant', 'science', 'health', 'credential', 'reliability', 'logistics', 'audit', 'consumer', 'saviynt', 'op', 'usds', 'option', 'federation', 'part', 'new', 'industry', 'ping', 'temp', 'innovation', 'epic', 'bi', 'vice', 'bis', 'enterprise', 'corporation', 'response', 'h', 'implementation', 'opportunity', 'hr', 'biometric', 'party', 'device', 'endpoint', 'technologies', 'compensation', 'change', 'payroll','basic', 'pasadena', 'third', 'beacon', 'machine', 'environmental', 'authentication', 'discovery', 'midlevel', 'database', 'enablement', 'wa', 'desk', 'infrastructure', 'technology', 'water', 'privilege', 'york', 'provisioning', 'delivery', 'salesforce', 'okta', 'group', 'wastewater', 'subsidiary', 'markets', 'benefits', 'jr', 'volunteer', 'firmware', 'schedule', 'solutions', 'development', 'products', 'marketing','foundational', 'available', 'oversight', 'aws', 'power', 'forgerock', 'virtual', 'duke', 'help', '2', 'risk', 'reporting', 'full', 'pam', 'platforms', 'c13', 'phc', 'exam', 'work', 'bellevue', 'us', 'tech', 'nj', 'cyberark', 'junior', 'back', 'experian', 'experience','fully', 'architecture', 'fraud', 'java', 'berkeley', 'working', 'kubernetes', 'linux', 'intelligence', 'scientist', 'monetization', '70', 'zero', '4', 'c360', '41278', 'executive_selling', '1235', 'workforce', '898168', 'verizon', 'time', 'mts', 'project', 'äîidentity', 'quality', 'coordinator', 'chief','0520u', 'o365','sql','hardware','master','flexible','3']

stopword.extend(newStopWords)

#Remove stopwords from tokenized words.
words_ne=[]
for word in words:
    if word not in stopword:
        words_ne.append(word)

# %% [markdown]
# ## 5. Create x-grams and frequency analysis

# %%
# Set n-grams value
n = 1
xgrams = ngrams(words_ne, n)

frequency = nltk.FreqDist(xgrams)

#Print key value list of xgrams
for key,value in frequency.items():
    if value > 0:
        print(key, value)

values = frequency.values()
total = sum(values)
print("The Total Number of Values =", total)
# Out:
# ('engineer',) 143
# ('analyst',) 75
# ('manager',) 51
# ('vp',) 8
# ('developer',) 34
# ('lead',) 19
# ('director',) 33
# ('associate',) 11
# ('specialist',) 10
# ('head',) 5
# ('architect',) 20
# ('principal',) 7
# ('officer',) 2
# ('leader',) 3
# ('administrator',) 16
# ('consultant',) 13
# ('supervisor',) 1
# ('strategist',) 2
# ('president',) 1
# ('expert',) 1
# The Total Number of Values = 455

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(frequency.items())

print(df)

plt.bar(df['0'], df['1'])
plt.title('Unique Work Roles', fontsize=14)
plt.xlabel('Work Role', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(True)
plt.show()
# Out:
#                    0    1
# 0        (engineer,)  143
# 1         (analyst,)   75
# 2         (manager,)   51
# 3              (vp,)    8
# 4       (developer,)   34
# 5            (lead,)   19
# 6        (director,)   33
# 7       (associate,)   11
# 8      (specialist,)   10
# 9            (head,)    5
# 10      (architect,)   20
# 11      (principal,)    7
# 12        (officer,)    2
# 13         (leader,)    3
# 14  (administrator,)   16
# 15     (consultant,)   13
# 16     (supervisor,)    1
# 17     (strategist,)    2
# 18      (president,)    1
# 19         (expert,)    1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [7], line 8
#       4 df = pd.DataFrame(frequency.items())
#       6 print(df)
# ----> 8 plt.bar(df['0'], df['1'])
#       9 plt.title('Unique Work Roles', fontsize=14)
#      10 plt.xlabel('Work Role', fontsize=14)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: '0'
